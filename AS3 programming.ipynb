# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
semidata = pd.read_csv('/Users/Jeffery/Google Drive/Homework/web data 590/As3/MIX_PANEL_DATA_semi-processed.csv',sep=',')

# %%
rawdata = pd.read_excel('/Users/Jeffery/Google Drive/Homework/web data 590/As3/rawMixPanelDump.xlsx')

# %%
semidata.head(1)
# Out:
#    Are_Record_Duplicate     Event                           Distinct ID  \
# 0                     0  Activate  DB2A8629-65C2-579C-539D-1C6503B8106A
#
#       City Region  Last_Lattitude  Last_Longitude  Games_Lost  Games_Started  \
# 0  Red Oak  Texas       32.503672      -96.803899          17             27
#
#    Games_Won  Number_of_Coins Invitee_Player_Key Inviter_Player_Key  \
# 0          7              429                NaN                NaN
#
#    Number_of_players_in_a_match                         Player_1_Key  \
# 0                             6  simpleheather.walker331388082910163
#
#                      Player_2_Key                   Player_3_Key  \
# 0  simplezmadrid19991387750904476  simpleconman10241388027756595
#
#                   Player_4_Key                     Player_5_Key  \
# 0  simpledarw12341388028388353  simplejkmadrid19721388542601353
#
#                        Player_6_Key
# 0  simpleghettorae19911388554635616

# %%
print(semidata.describe())
print('shape:',semidata.shape)
# Out:
#        Are_Record_Duplicate  Last_Lattitude  Last_Longitude    Games_Lost  \
# count          36189.000000    28563.000000    28563.000000  36189.000000
# mean               0.117688       35.057048      -77.525628      2.773329
# std                0.322242       18.114601       57.818491      4.143602
# min                0.000000      -42.782924     -155.896962      0.000000
# 25%                0.000000       33.964846      -96.848314      0.000000
# 50%                0.000000       39.985693      -87.715723      1.000000
# 75%                0.000000       41.888085      -78.672500      4.000000
# max                1.000000       60.954655      153.203481     29.000000
#
#        Games_Started     Games_Won  Number_of_Coins  \
# count   36189.000000  36189.000000     36189.000000
# mean        6.122523      1.531101       644.569704
# std         7.689424      2.644081      3384.645877
# min         0.000000      0.000000         0.000000
# ...

# %%
rawdata.head(1)
# Out:
#         event                           distinct_id       $city  $region  \
# 0  ViewScreen  A384B1BB-3289-CFCE-4F72-381F2517BFAD  Lethbridge  Alberta
#
#    accountCreationTime comment  couldAfford error errorEvent  errorID  \
# 0         1.388216e+12     NaN          NaN   NaN        NaN      NaN
#
#        ...        sessionId sessionStartTime stackTrace store testGroup  \
# 0      ...              NaN              NaN        NaN   NaN       NaN
#
#    testGroup2  testPeriod  theme          time  versionNumber
# 0         NaN         NaN    NaN  1.388534e+09        1.1.000
#
# [1 rows x 85 columns]

# %%
print(rawdata.describe())
print('shape:',rawdata.shape)
# Out:
#        accountCreationTime   couldAfford      errorID      errorId  \
# count         2.194300e+05  1.909000e+03   753.000000   966.000000
# mean          1.364173e+12  5.502880e+08   115.597610    62.826087
# std           1.956063e+11  6.820014e+08   396.481039   306.038219
# min           0.000000e+00  0.000000e+00     0.000000     0.000000
# 25%           1.390192e+12  0.000000e+00     0.000000     0.000000
# 50%           1.392047e+12  0.000000e+00     0.000000    22.000000
# 75%           1.394155e+12  1.395056e+09     0.000000    23.000000
# max           1.396326e+12  1.396303e+09  2030.000000  2038.000000
#
#        gamesFinished      gamesLost   gamesStarted       gamesWon  \
# count       219430.0  219430.000000  219430.000000  219430.000000
# mean             0.0       1.409092       3.018562       0.754760
# std              0.0       3.251682       6.616542       1.958241
# min              0.0       0.000000       0.000000       0.000000
# ...

# %%
print(rawdata.columns.values)
# Out:
# [u'event' u'distinct_id' u'$city' u'$region' u'accountCreationTime'
#  u'comment' u'couldAfford' u'error' u'errorEvent' u'errorID' u'errorId'
#  u'errorMessage' u'errorName' u'errorStr' u'errorType' u'gamesFinished'
#  u'gamesLost' u'gamesStarted' u'gamesWon' u'hasCherry' u'hasPlum'
#  u'hasWatermelon' u'installId' u'installTime' u'inviteePlayerKey'
#  u'inviterIsIncentivized' u'inviterPlayerKey' u'inviterTestGroup'
#  u'inviterTestGroup2' u'isAppUpdate' u'isExistingUser'
#  u'isInIncentivizedPeriod' u'isInstall' u'isOSUpdate'
#  u'isPreIncentiveExperimentUser' u'isSessionTimeout' u'isWifi' u'isWin'
#  u'item' u'lastLatitude' u'lastLocationAccuracy' u'lastLocationTime'
#  u'lastLongitude' u'latitude' u'launchDuration' u'launchEndTime'
#  u'launchId' u'launchStartTime' u'leftFeedback' u'locationAccuracy'
#  u'locationTime' u'loggedIn' u'longitude' u'matchId' u'matchNumPlayers'
#  u'matchPlayerKey1' u'matchPlayerKey2' u'matchPlayerKey3'
# ...

# %%
print(semidata.columns.values)
# Out:
# ['Are_Record_Duplicate' 'Event' 'Distinct ID' 'City' 'Region'
#  'Last_Lattitude' 'Last_Longitude' 'Games_Lost' 'Games_Started' 'Games_Won'
#  'Number_of_Coins' 'Invitee_Player_Key' 'Inviter_Player_Key'
#  'Number_of_players_in_a_match' 'Player_1_Key' 'Player_2_Key'
#  'Player_3_Key' 'Player_4_Key' 'Player_5_Key' 'Player_6_Key']

# %%
print(semidata.corr())
# Out:
#                               Are_Record_Duplicate  Last_Lattitude  \
# Are_Record_Duplicate                      1.000000       -0.025788
# Last_Lattitude                           -0.025788        1.000000
# Last_Longitude                            0.027268       -0.818641
# Games_Lost                               -0.021143        0.047252
# Games_Started                            -0.020540        0.085653
# Games_Won                                -0.013036        0.124784
# Number_of_Coins                           0.000373       -0.113649
# Number_of_players_in_a_match             -0.003353       -0.059633
#
#                               Last_Longitude  Games_Lost  Games_Started  \
# Are_Record_Duplicate                0.027268   -0.021143      -0.020540
# Last_Lattitude                     -0.818641    0.047252       0.085653
# Last_Longitude                      1.000000    0.009494      -0.010714
# Games_Lost                          0.009494    1.000000       0.904813
# ...

# %%
rawdata.corr()
# Out:
#                               accountCreationTime  couldAfford   errorID  \
# accountCreationTime                      1.000000    -0.179882  0.274605
# couldAfford                             -0.179882     1.000000       NaN
# errorID                                  0.274605          NaN  1.000000
# errorId                                  0.010880          NaN       NaN
# gamesFinished                                 NaN          NaN       NaN
# gamesLost                               -0.093203     0.358538  0.317257
# gamesStarted                            -0.287229     0.396893 -0.472758
# gamesWon                                -0.073824     0.339988  0.182924
# hasCherry                                0.004366     0.041009 -0.032050
# hasPlum                                  0.007251     0.046592 -0.032050
# hasWatermelon                            0.003887     0.071690 -0.032050
# installTime                              0.046297     0.016158  0.285626
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(context="paper", font="monospace")

# Load the datset of correlations between cortical brain networks
corrmat = rawdata.corr()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 20))

# Draw the heatmap using seaborn
sns.heatmap(corrmat, vmax=.8, square=True)

f.tight_layout()
plt.xticks(rotation = 90)
plt.yticks(rotation = 0)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(context="paper", font="monospace")

# Load the datset of correlations between cortical brain networks
corrmat = semidata.corr()

# Set up the matplotlib figure
a, ax = plt.subplots(figsize=(20, 20))

# Draw the heatmap using seaborn
sns.heatmap(corrmat, vmax=.8, square=True)

a.tight_layout()
plt.xticks(rotation = 90)
plt.yticks(rotation = 0)
plt.show()
